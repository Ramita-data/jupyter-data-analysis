# %%
import pandas as pd

df = pd.read_csv(r"C:\Users\Ramita\Downloads\structured_data.csv")
print(df.head())  # Display first few rows
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156  2016-11-08  2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688  2016-06-12  2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966  2015-10-11  2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
import pandas as pd

# Convert "Order Date" to datetime format
df["Order Date"] = pd.to_datetime(df["Order Date"])

# Filter for year 2017 and Ship Mode "Second Class"
df_2017_second_class = df[(df["Order Date"].dt.year == 2017) & (df["Ship Mode"] == "Second Class")]

# Display first few rows
df_2017_second_class.head()
# Out:
#     Row ID        Order ID Order Date   Ship Date     Ship Mode Customer ID  \
# 23      24  US-2017-156909 2017-07-16  2017-07-18  Second Class    SF-20065
# 34      35  CA-2017-107727 2017-10-19  2017-10-23  Second Class    MA-17560
# 71      72  CA-2017-114440 2017-09-14  2017-09-17  Second Class    TB-21520
# 85      86  CA-2017-140088 2017-05-28  2017-05-30  Second Class    PO-18865
# 96      97  CA-2017-161018 2017-11-09  2017-11-11  Second Class    PN-18775
#
#         Customer Name      Segment        Country           City  ...  \
# 23    Sandra Flanagan     Consumer  United States   Philadelphia  ...
# 34       Matt Abelman  Home Office  United States        Houston  ...
# 71    Tracy Blumstein     Consumer  United States        Jackson  ...
# 85  Patrick O'Donnell     Consumer  United States       Columbia  ...
# 96     Parhena Norris  Home Office  United States  New York City  ...
#
#    Postal Code   Region       Product ID         Category Sub-Category  \
# ...

# %%
import pandas as pd

# Load CSV file
file_path = r"C:\Users\Ramita\Desktop\Rami.csv"
df = pd.read_csv(file_path)

# Display basic info
df.info()
df.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73 entries, 0 to 72
# Data columns (total 11 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   product_id     72 non-null     float64
#  1   brand_name     72 non-null     object
#  2   title          72 non-null     object
#  3   current_price  72 non-null     float64
#  4   quantity       72 non-null     float64
#  5   date           73 non-null     int64
#  6   currency       72 non-null     object
#  7   rrp            36 non-null     float64
#  8   productCode    72 non-null     float64
#  9   productType    72 non-null     object
#  10  sales          72 non-null     float64
# dtypes: float64(6), int64(1), object(4)
# memory usage: 6.4+ KB
#     product_id         brand_name  \
# 0  204499665.0             Replay
# 1  203420859.0       Jack & Jones
# 2  204285229.0       Jack & Jones
# 3  202261918.0  Don't Think Twice
# 4  202191610.0  Another Influence
#
# ...
